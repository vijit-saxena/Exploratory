# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("/home/vijit668/Desktop/Analiticity/train.csv")
# Out:
# /home/vijit/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-7d0f3c067fc5> in <module>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 df = pd.read_csv("/home/vijit668/Desktop/Analiticity/train.csv")
#
# ...

# %%
df.fillna()
# Out:
#       LOAN_ID  AMOUNT  DUE_MORTGAGE     VALUE  REASON  OCC  TJOB  DCL  \
# 0     3682648   15100       71168.0   97480.0     1.0  0.0   9.0  0.0
# 1     3682649   21100       81747.0  109840.0     1.0  0.0   NaN  0.0
# 2     3682650   15900       94262.0  128414.0     1.0  3.0   4.0  NaN
# 3     3682651   12900      110899.0  124480.0     1.0  2.0   7.0  0.0
# 4     3682652   24600           NaN   35523.0     0.0  0.0  21.0  0.0
# 5     3682653   15000       65742.0   86608.0     0.0  0.0   NaN  0.0
# 6     3682654   22800       75253.0  106166.0     1.0  0.0   NaN  0.0
# 7     3682655   23200      133766.0  174085.0     NaN  3.0  26.0  3.0
# 8     3682656   11900      117952.0  125305.0     1.0  5.0   5.0  0.0
# 9     3682657   13700       55763.0   87480.0     1.0  4.0   9.0  0.0
# 10    3682658    7000       49831.0   66022.0     0.0  1.0  20.0  0.0
# 11    3682659   34200      138422.0  196535.0     1.0  4.0  21.0  0.0
# ...

# %%
df.describe()
# Out:
#             LOAN_ID        AMOUNT   DUE_MORTGAGE          VALUE       REASON  \
# count  3.576000e+03   3576.000000    3258.000000    3509.000000  3419.000000
# mean   3.684436e+06  18593.596197   74028.507532  101706.385571     0.690553
# std    1.032447e+03  10901.127719   44716.291776   55426.276328     0.462333
# min    3.682648e+06   1200.000000    1962.000000    7980.000000     0.000000
# 25%    3.683542e+06  11200.000000   46546.750000   66395.000000     0.000000
# 50%    3.684436e+06  16400.000000   65849.500000   89569.000000     1.000000
# 75%    3.685329e+06  23200.000000   91288.000000  120159.000000     1.000000
# max    3.686223e+06  89900.000000  399449.000000  849980.000000     1.000000
#
#                OCC         TJOB          DCL          CLT     CL_COUNT  \
# count  3403.000000  3267.000000  3239.000000  3389.000000  3446.000000
# mean      1.666765     8.895301     0.428836   181.339737    21.161056
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

ax=df.boxplot(column='CL_COUNT', by = 'DEFAULTER')
plt.show()
# Out:
# /home/vijit668/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
pc=df.groupby(['VAR_1','DEFAULTER'])
pc.count()
# Out:
#                  LOAN_ID  AMOUNT  DUE_MORTGAGE  VALUE  REASON   OCC  TJOB  \
# VAR_1 DEFAULTER
# 0     0             2628    2628          2395   2624    2503  2476  2390
#       1              505     505           452    466     489   498   472
# 1     0              174     174           163    174     165   166   159
#       1              102     102            95     90     100    98    96
# 2     0               52      52            51     52      52    52    43
#       1               46      46            43     38      43    45    45
# 3     0                5       5             5      5       5     5     5
#       1               25      25            23     24      24    25    24
# 4     0                4       4             4      4       4     4     4
#       1               11      11             9     10      10    10    11
# 5     0                3       3             0      3       3     3     0
# ...

# %%
# Out:
# /home/vijit668/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
arr = [2628,505,174,102,52,46,5,25,4,11,3,3,3,5,0,3,0,4,0,2,0,1]
arr = np.asarray(arr)
arr = np.reshape(arr, (11,2))
arr
row_mul=[]
col_mul=[]
for i in range(11):
    row_mul.append(arr[i][0]*arr[i][1])
for j in range(2):
    mul = 1
    for i in range(11):
        mul = mul * arr[i][j]
    col_mul.append(mul)

# %%
col_mul
# Out:
# [0, 234576540000]

# %%
row_mul
# Out:
# [1327140, 17748, 2392, 125, 44, 9, 15, 0, 0, 0, 0]

# %%
E =[]
add = 0
for i in row_mul:
    for j in col_mul:
        E.append(i*j/sum(arr))
E = np.asarray(E)
perc = 0
for i in range(11):
    for j in range(2):
        perc = perc + (arr[i][j]-E[i][j])*(arr[i][j]-E[i][j])/E[i][j]
perc
# Out:
# /home/vijit668/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.
# /home/vijit668/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.
# inf

# %%
df.apply(lambda x:sum(x.isnull()))
# Out:
# LOAN_ID           0
# AMOUNT            0
# DUE_MORTGAGE    318
# VALUE            67
# REASON          157
# OCC             173
# TJOB            309
# DCL             337
# CLT             187
# CL_COUNT        130
# RATIO           751
# CONVICTED         0
# VAR_1             0
# VAR_2             0
# VAR_3             0
# DEFAULTER         0
# dtype: int64

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
fd = pd.read_csv("/home/vijit/anaconda3/lib/python3.6/site-packages/sklearn/datasets/data/iris.csv")

# %%
fd
# Out:
#      150    4  setosa  versicolor  virginica
# 0    5.1  3.5     1.4         0.2          0
# 1    4.9  3.0     1.4         0.2          0
# 2    4.7  3.2     1.3         0.2          0
# 3    4.6  3.1     1.5         0.2          0
# 4    5.0  3.6     1.4         0.2          0
# 5    5.4  3.9     1.7         0.4          0
# 6    4.6  3.4     1.4         0.3          0
# 7    5.0  3.4     1.5         0.2          0
# 8    4.4  2.9     1.4         0.2          0
# 9    4.9  3.1     1.5         0.1          0
# 10   5.4  3.7     1.5         0.2          0
# 11   4.8  3.4     1.6         0.2          0
# 12   4.8  3.0     1.4         0.1          0
# 13   4.3  3.0     1.1         0.1          0
# 14   5.8  4.0     1.2         0.2          0
# 15   5.7  4.4     1.5         0.4          0
# 16   5.4  3.9     1.3         0.4          0
# 17   5.1  3.5     1.4         0.3          0
# 18   5.7  3.8     1.7         0.3          0
# 19   5.1  3.8     1.5         0.3          0
# ...

# %%
iris = load_iris

# %%
# Out:
# <function load_iris at 0x7fd909670ae8>
