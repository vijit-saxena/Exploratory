# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Graphs depicting co-relation amoung features

# %%
file1 = pd.read_csv("train_change1.01.csv")

# %%
file1
# Out:
#       Unnamed: 0  AMOUNT   DUE_MORTGAGE     VALUE  REASON  OCC  TJOB  DCL  \
# 0              0   15100   71168.000000   97480.0     1.0  0.0   9.0  0.0
# 1              1   21100   81747.000000  109840.0     1.0  0.0   2.0  0.0
# 2              2   15900   94262.000000  128414.0     1.0  3.0   4.0  0.0
# 3              3   12900  110899.000000  124480.0     1.0  2.0   7.0  0.0
# 4              4   24600   74028.507532   35523.0     0.0  0.0  21.0  0.0
# 5              5   15000   65742.000000   86608.0     0.0  0.0   2.0  0.0
# 6              6   22800   75253.000000  106166.0     1.0  0.0   2.0  0.0
# 7              7   23200  133766.000000  174085.0     1.0  3.0  26.0  3.0
# 8              8   11900  117952.000000  125305.0     1.0  5.0   5.0  0.0
# 9              9   13700   55763.000000   87480.0     1.0  4.0   9.0  0.0
# 10            10    7000   49831.000000   66022.0     0.0  1.0  20.0  0.0
# 11            11   34200  138422.000000  196535.0     1.0  4.0  21.0  0.0
# ...

# %%
plt.hist(file1.AMOUNT)
# Out:
# (array([ 667., 1488.,  950.,  255.,  111.,   66.,   12.,   11.,    9.,
#            7.]),
#  array([ 1200., 10070., 18940., 27810., 36680., 45550., 54420., 63290.,
#         72160., 81030., 89900.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(file1.DUE_MORTGAGE)
# Out:
# (array([6.430e+02, 1.855e+03, 6.770e+02, 2.690e+02, 6.400e+01, 5.300e+01,
#         4.000e+00, 1.000e+00, 1.000e+00, 9.000e+00]),
#  array([  1962. ,  41710.7,  81459.4, 121208.1, 160956.8, 200705.5,
#         240454.2, 280202.9, 319951.6, 359700.3, 399449. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(file1.VALUE)
# Out:
# (array([1.856e+03, 1.391e+03, 2.620e+02, 5.600e+01, 2.000e+00, 8.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  7980.,  92180., 176380., 260580., 344780., 428980., 513180.,
#         597380., 681580., 765780., 849980.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(file1.TJOB)
# Out:
# (array([1451.,  741.,  528.,  313.,  198.,  176.,  110.,   50.,    6.,
#            3.]),
#  array([ 0. ,  4.1,  8.2, 12.3, 16.4, 20.5, 24.6, 28.7, 32.8, 36.9, 41. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(file1.CLT)
# Out:
# (array([ 135.,  951., 1115.,  750.,  436.,  153.,   21.,    5.,    0.,
#           10.]), array([  1.        ,  64.90581723, 128.81163446, 192.71745169,
#         256.62326892, 320.52908615, 384.43490338, 448.34072061,
#         512.24653784, 576.15235507, 640.0581723 ]), <a list of 10 Patch objects>)

# %%
plt.hist(file1.RATIO)
# Out:
# (array([4.000e+01, 6.900e+02, 2.768e+03, 6.300e+01, 1.200e+01, 2.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  0.73029501,  15.05322601,  29.37615701,  43.699088  ,
#          58.022019  ,  72.34495   ,  86.667881  , 100.990812  ,
#         115.313743  , 129.636674  , 143.959605  ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(file1.VAR_3)
# Out:
# (array([ 95., 178., 215., 344., 440., 476., 504., 506., 434., 384.]),
#  array([0.045274 , 0.3186466, 0.5920192, 0.8653918, 1.1387644, 1.412137 ,
#         1.6855096, 1.9588822, 2.2322548, 2.5056274, 2.779    ]),
#  <a list of 10 Patch objects>)
